# %% [raw]
# For this assignment you need to:
#     Prepare the data - stopwords, stemming
#     Apply both: bag of words and tfIdf
#     Apply Logistic Regression, SVM, and NaiveBayes for the ready dataset
#     Compare accuracies for bag of words and tfidf with all the algorithms above

# %%
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv("data.tsv", delimiter="\t")
data = data[:1000]
data
# Out:
#      PhraseId  SentenceId                                             Phrase  \
# 0           1           1  A series of escapades demonstrating the adage ...
# 1           2           1  A series of escapades demonstrating the adage ...
# 2           3           1                                           A series
# 3           4           1                                                  A
# 4           5           1                                             series
# 5           6           1  of escapades demonstrating the adage that what...
# 6           7           1                                                 of
# 7           8           1  escapades demonstrating the adage that what is...
# 8           9           1                                          escapades
# 9          10           1  demonstrating the adage that what is good for ...
# 10         11           1                            demonstrating the adage
# 11         12           1                                      demonstrating
# 12         13           1                                          the adage
# 13         14           1                                                the
# 14         15           1                                              adage
# 15         16           1                    that what is good for the goose
# 16         17           1                                               that
# 17         18           1                         what is good for the goose
# 18         19           1                                               what
# 19         20           1                              is good for the goose
# 20         21           1                                                 is
# 21         22           1                                 good for the goose
# 22         23           1                                               good
# 23         24           1                                      for the goose
# 24         25           1                                                for
# 25         26           1                                          the goose
# 26         27           1                                              goose
# 27         28           1  is also good for the gander , some of which oc...
# 28         29           1  is also good for the gander , some of which oc...
# 29         30           1                                            is also
# ..        ...         ...                                                ...
# 970       971          36  They 're the unnamed , easily substitutable fo...
# 971       972          36                                               They
# 972       973          36  're the unnamed , easily substitutable forces ...
# 973       974          36  're the unnamed , easily substitutable forces ...
# 974       975          36                                                're
# 975       976          36  the unnamed , easily substitutable forces that...
# 976       977          36          the unnamed , easily substitutable forces
# 977       978          36              unnamed , easily substitutable forces
# 978       979          36                     unnamed , easily substitutable
# 979       980          36                                            unnamed
# 980       981          36                             , easily substitutable
# 981       982          36                               easily substitutable
# 982       983          36                                             easily
# 983       984          36                                      substitutable
# 984       985          36                                             forces
# 985       986          36  that serve as whatever terror the heroes of ho...
# 986       987          36  serve as whatever terror the heroes of horror ...
# 987       988          36  as whatever terror the heroes of horror movies...
# 988       989          36  whatever terror the heroes of horror movies tr...
# 989       990          36                                           whatever
# 990       991          36    terror the heroes of horror movies try to avoid
# 991       992          36                                             terror
# 992       993          36           the heroes of horror movies try to avoid
# 993       994          36                        the heroes of horror movies
# 994       995          36                                         the heroes
# 995       996          36                                             heroes
# 996       997          36                                   of horror movies
# 997       998          36                                      horror movies
# 998       999          36                                             horror
# 999      1000          36                                       try to avoid
#
#      Sentiment
# 0            1
# 1            2
# 2            2
# 3            2
# 4            2
# 5            2
# 6            2
# 7            2
# 8            2
# 9            2
# 10           2
# 11           2
# 12           2
# 13           2
# 14           2
# 15           2
# 16           2
# 17           2
# 18           2
# 19           2
# 20           2
# 21           3
# 22           3
# 23           2
# 24           2
# 25           2
# 26           2
# 27           2
# 28           2
# 29           2
# ..         ...
# 970          1
# 971          2
# 972          1
# 973          2
# 974          2
# 975          1
# 976          1
# 977          2
# 978          1
# 979          2
# 980          1
# 981          2
# 982          3
# 983          1
# 984          2
# 985          2
# 986          2
# 987          2
# 988          1
# 989          1
# 990          1
# 991          1
# 992          1
# 993          2
# 994          2
# 995          3
# 996          2
# 997          2
# 998          1
# 999          1
#
# [1000 rows x 4 columns]

# %%
import re # Regular Expression
from string import punctuation

lst = []
stop = set(stopwords.words('english'))
phrase = data['Phrase']
for words in phrase:
    for word in words.split(" "):
        word = re.sub('[^A-Za-z]+', '', word.lower())
        if word not in stop and word not in punctuation:
            lst += [word]
stopped = set(lst)

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
lst = []
for word in stopped:
    lst += [ps.stem(word)]
stemmed = set(lst)
